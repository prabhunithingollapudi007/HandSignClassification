# %%
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.applications.vgg16 import preprocess_input
# Out:
# c:\python\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def get_data_array(file_path):
    with open(file_path) as src_file:
        data_array = np.empty((303360, 4))
        for index, line in enumerate(src_file.readlines()):
            data_array[index] = [int(x) for x in line.split()]    
        data_array = np.reshape(data_array, (480, 632, 4))
        data_array = data_array.astype(np.uint8)
        return data_array

# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
zeros_train = glob('../raw_data/data/train/Zero/*.txt')
ones_train = glob('../raw_data/data/train/One/*.txt')
twos_train = glob('../raw_data/data/train/Two/*.txt')

threes_train = glob('../raw_data/data/train/Three/*.txt')
fours_train = glob('../raw_data/data/train/Four/*.txt')
fives_train = glob('../raw_data/data/train/Five/*.txt')

sixes_train = glob('../raw_data/data/train/Six/*.txt')
sevens_train = glob('../raw_data/data/train/Seven/*.txt')
eights_train = glob('../raw_data/data/train/Eight/*.txt')
nines_train = glob('../raw_data/data/train/Nine/*.txt')

# %%
zeros_test = glob('../raw_data/data/test/Zero/*.txt')
ones_test = glob('../raw_data/data/test/One/*.txt')
twos_test = glob('../raw_data/data/test/Two/*.txt')

threes_test = glob('../raw_data/data/test/Three/*.txt')
fours_test = glob('../raw_data/data/test/Four/*.txt')
fives_test = glob('../raw_data/data/test/Five/*.txt')

sixes_test = glob('../raw_data/data/test/Six/*.txt')
sevens_test = glob('../raw_data/data/test/Seven/*.txt')
eights_test = glob('../raw_data/data/test/Eight/*.txt')
nines_test = glob('../raw_data/data/test/Nine/*.txt')

# %%
temp = []
for file in zeros_train:
    temp.append(get_data_array(file))

# %%
temp = np.array(temp)

# %%
temp.shape
# Out:
# (10, 480, 632, 4)

# %%
from PIL import Image

# %%
fg = Image.fromarray(temp[8][:, :, 3])
fg
# Out:
# <PIL.Image.Image image mode=L size=632x480 at 0x1E7F6F66BA8>

# %%
plt.imshow(fg)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
#create model
model = Sequential()
#add model layers
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(480,632,4)))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-fc741c0fcff2> in <module>()
#       2 from keras.layers import Dense, Conv2D, Flatten
#       3 #create model
# ----> 4 model = Sequential()
#       5 #add model layers
#       6 model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(480,632,4)))
#
# C:\Users\Nithin\AppData\Roaming\Python\Python36\site-packages\keras\models.py in __init__(self, layers, name)
#     400         if not name:
#     401             prefix = 'sequential_'
# --> 402             name = prefix + str(K.get_uid(prefix))
#     403         self.name = name
#     404
#
# C:\Users\Nithin\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py in get_uid(prefix)
#      62     """
#      63     global _GRAPH_UID_DICTS
# ---> 64     graph = tf.get_default_graph()
#      65     if graph not in _GRAPH_UID_DICTS:
#      66         _GRAPH_UID_DICTS[graph] = defaultdict(int)
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'
